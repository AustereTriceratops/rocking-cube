# %%
import random
from constants import *
from moves import *
from analysis import *

edges = [i for i in START_EDGES]

# %%
for _ in range(10):
  permuted_edges, moves = randomOrientedPermutation(9)

  fixed_edges = fixedRelativeTo(START_EDGES, permuted_edges)
  permutation_order = permutationOrder(moves)
  print(moves)
  print(permutation_order)
# Out:
# R'LR'L'R'LRL'R'
# 7
# LRLRLR'LRLLR
# 7
# R'L'RLR'LR'LRLR
# 7
# LR'LR'LR'L'R'LR
# 7
# R'L'R'LRL'RL'RL'R'
# 3
# R'LR'LR'L'RLRLR
# 7
# R'L'R'L'R'LR'L'R'L'R'
# 6
# R'L'RL'R'L'R'LR'L'
# 6
# LRL'R'LR'L'RLL'
# 7
# LRL'RL'RL'R'L'R
# 7

# %%
for _ in range(5000):
  permuted_edges, moves = randomOrientedPermutation(16)

  fixed_edges = fixedRelativeTo(edges, permuted_edges)

  if len(fixed_edges) > 2:
    print(moves)
    print(fixed_edges)
# Out:
# LRL'R'LR'LRL'R'LR'LRL'R'LR'
# {'BOd', 'WB', 'WR', 'YB', 'WG', 'YR', 'YO', 'GRd', 'GRu', 'GO', 'WO', 'YG', 'BOu', 'BR'}

# %%
format(37, "08b")
# Out:
# '00100101'

# %%
search_depth = 4
N = 2**(search_depth + 1)
generated_moves = []

for i in range(N):
  ib = format(i, f'0{search_depth + 1}b') # convert to binary with leading 0s
  moves = []
  prevMoveType = ""
  
  if ib[0] == "0":
    prevMoveType = "R"
  elif ib[0] == "1":
    prevMoveType = "L"
  
  for j in range(search_depth):
    if ib[j + 1] == "0":
      if prevMoveType == "L":
        moves.append("R")
        prevMoveType = "R"
      elif prevMoveType == "R":
        moves.append("L")
        prevMoveType = "L"
    elif ib[j + 1] == "1":
      if prevMoveType == "L":
        moves.append("R'")
        prevMoveType = "R"
      elif prevMoveType == "R":
        moves.append("L'")
        prevMoveType = "L"
  
  generated_moves.append("".join(moves))

# %%
generated_moves
# Out:
# ['LRLR',
#  "LRLR'",
#  "LRL'R",
#  "LRL'R'",
#  "LR'LR",
#  "LR'LR'",
#  "LR'L'R",
#  "LR'L'R'",
#  "L'RLR",
#  "L'RLR'",
#  "L'RL'R",
#  "L'RL'R'",
#  "L'R'LR",
#  "L'R'LR'",
#  "L'R'L'R",
#  "L'R'L'R'",
#  'RLRL',
#  "RLRL'",
#  "RLR'L",
#  "RLR'L'",
#  "RL'RL",
#  "RL'RL'",
#  "RL'R'L",
#  "RL'R'L'",
#  "R'LRL",
#  "R'LRL'",
#  "R'LR'L",
#  "R'LR'L'",
#  "R'L'RL",
#  "R'L'RL'",
#  "R'L'R'L",
#  "R'L'R'L'"]

# %%
len(generated_moves)
# Out:
# 32
